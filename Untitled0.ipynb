# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivan241/Coding-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
string = "Hello"
if 'o' in string :
  print("o exist in string")
# Out:
# o exist in string

# %%
for ch in word:

    if ch in "aeiou":
        count += 1

print("number of vowels =", count)
# Out:
# number of vowels = 5

# %%
for i in range (1,10,2):
 print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
a = (float(input("Enter the value of a:")))
b = (float(input("Enter the value of b:")))
print("Sum=",a+b)
print("diffeerence=",a-b)
print("product=",a*b)
print("quotient=",a//b)
# Out:
# Enter the value of a:2
# Enter the value of b:1
# Sum= 3.0
# diffeerence= 1.0
# product= 2.0
# quotient= 2.0

# %%
a=int(input("Enter the integer:"))
b=int(input("Enter the integer:"))
c=float(input("Enter the float number:"))
x=float(a)
y=float(b)
print("Average",(x+y+c)/3)
# Out:
# Enter the integer:3
# Enter the integer:2
# Enter the float number:1
# Average 2.0
